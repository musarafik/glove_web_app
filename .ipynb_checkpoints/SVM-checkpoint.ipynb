# reading__P3r1       -0.168289      -0.035932       0.011658             NaN
# reading__P4r1       -0.141925      -0.030458       0.026153             NaN
# ...                       ...            ...            ...             ...
# reading_gx2r5        1.000000      -0.038226       0.023437             NaN
# reading_gy2r5       -0.038226       1.000000      -0.024568             NaN
# reading_gz2r5        0.023437      -0.024568       1.000000             NaN
# 2reading_nc1r5            NaN            NaN            NaN             NaN
# 2reading_nc2r5            NaN            NaN            NaN             NaN
#
#                 2reading_nc2r5
# reading__P0r1              NaN
# reading__P1r1              NaN
# reading__P2r1              NaN
# reading__P3r1              NaN
# reading__P4r1              NaN
# ...                        ...
# reading_gx2r5              NaN
# reading_gy2r5              NaN
# reading_gz2r5              NaN
# 2reading_nc1r5             NaN
# 2reading_nc2r5             NaN
#
# [200 rows x 200 columns]

# %%
# Insert dataset of columns for each sensor value and final column of which letter it corresponds to
SensorData = pd.read_csv('reformated_A-G_Sunday.csv')
# Converting data to Panda DataFrame
df = pd.DataFrame(SensorData) 
df.head()
# Out:
#   sign  reading__P0r1  reading__P1r1  reading__P2r1  reading__P3r1  \
# 0    A       2.091536       1.469554       1.730593       1.720925
# 1    A       2.091536       1.708034       1.917510       1.846610
# 2    A       2.091536       1.737038       1.943291       1.836942
# 3    A       2.091536       1.753152       1.959405       1.859501
# 4    A       2.094759       1.775711       1.940069       1.869169
#
#    reading__P4r1  reading__P5r1  reading__P6r1  reading__P7r1  reading__P0r2  \
# 0       1.511449       0.000000       0.000000       0.000000       2.091536
# 1       1.740261       0.000000       0.000000       0.003223       2.091536
# 2       1.759597       0.000000       0.003223       0.000000       2.091536
# 3       1.749929       0.003223       0.415729       0.000000       2.094759
# 4       1.733816       0.000000       0.538192       0.000000       2.091536
#
#    ...  2reading_nc1r4  2reading_nc2r4  reading_gx1r5  reading_gy1r5  \
# 0  ...              -1              -1          65304          63671
# 1  ...              -1              -1             73             41
# 2  ...              -1              -1          64164           1013
# 3  ...              -1              -1          62303          65015
# 4  ...              -1              -1            725          62554
#
#    reading_gz1r5  reading_gx2r5  reading_gy2r5  reading_gz2r5  2reading_nc1r5  \
# 0          64136          60533          62918          65509              -1
# 1          64707            579            679          65521              -1
# 2            859            138            439            255              -1
# 3           4582          63487           1187           2486              -1
# 4            928           1461          63394           3949              -1
#
#    2reading_nc2r5
# 0              -1
# 1              -1
# 2              -1
# 3              -1
# 4              -1
#
# [5 rows x 201 columns]

# %%
# Visualizing the data to see the correlations
sns.pairplot(df)

# %%
# More data visualization
sns.heatmap(df.corr(), annot=True)

# %%
test = df['Letter']
train = df.drop(['Letter'], axis = 1)

# %%
# LOAD LIBRARIES
from sklearn.svm import SVC
from sklearn.feature_selection import VarianceThreshold
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import roc_auc_score
from sklearn import metrics

# Split training data
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(train, test, test_size=0.40, random_state=42)

# %%
svc=SVC(kernel='linear')
svc.fit(X_train,y_train)
y_pred=svc.predict(X_test)
print('Accuracy Score:')
print(metrics.accuracy_score(y_test,y_pred))

# %%
print(y_pred)

# %%
import pickle
s = pickle.dumps(svc)
svc2 = pickle.loads(s)
svc2.predict(X_test)

# %%
from joblib import dump, load
dump(svc, 'filename.joblib')

# %%
# Loads pickle model
svc = load('filename.joblib')
